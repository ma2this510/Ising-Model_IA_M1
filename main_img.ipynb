# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('./mydata/couche_O.O_4.0_1000.dat')
data = data.T
data.shape
# Out:
# (1600, 1000)

# %%
plt.figure(figsize=(12, 12)) 
plt.imshow(data, cmap='winter', extent=[0, 4, 0, 1], origin='lower', interpolation='none')
plt.gca().set_yticks([])
plt.xlabel('Temperature')
# Out:
# Text(0.5, 0, 'Temperature')
